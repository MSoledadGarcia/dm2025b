# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 06 de septiembre a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Sep 01 21:19:41 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656930 35.1 1439368    76.9 1431349  76.5
# Vcells 1224983  9.4 8388608    64.0 1924961  14.7

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4940.3
PARAM$semilla_primigenia <- 100019

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-b"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_col_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= TRUE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 0, # <=0 means no limit
  skip_drop= 0, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.2),
  makeNumericParam("feature_fraction", lower= 0.6, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 31L, upper= 256L),
  makeIntegerParam("min_data_in_leaf", lower= 20L, upper= 1000L),
    makeNumericParam("bagging_fraction", lower= 0.6, upper= 1.0),
    makeIntegerParam("bagging_freq", lower= 1L, upper= 10L),
    makeNumericParam("lambda_l1", lower= 0.0, upper= 5.0),
    makeNumericParam("lambda_l2", lower= 0.0, upper= 5.0),
    makeNumericParam("min_gain_to_split", lower= 0.0, upper= 1.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83617
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Sep 01 21:20:42 2025 AUC 0.920424632544103
#
# Mon Sep 01 21:21:26 2025 AUC 0.928595966582619
#
# Mon Sep 01 21:21:59 2025 AUC 0.925398083391068
#
# Mon Sep 01 21:23:00 2025 AUC 0.919198362996654
#
# Mon Sep 01 21:23:25 2025 AUC 0.921575702308054
#
# Mon Sep 01 21:23:54 2025 AUC 0.916588891248229
#
# Mon Sep 01 21:24:46 2025 AUC 0.92719413411024
#
# Mon Sep 01 21:25:58 2025 AUC 0.926049305257898
#
# Mon Sep 01 21:27:05 2025 AUC 0.923085124710534
#
# Mon Sep 01 21:27:46 2025 AUC 0.917040321890237
#
# Mon Sep 01 21:28:09 2025 AUC 0.916987194724142
#
# Mon Sep 01 21:28:54 2025 AUC 0.928298888621081
#
# Mon Sep 01 21:29:40 2025 AUC 0.927062334277971
#
# Mon Sep 01 21:30:26 2025 AUC 0.921779752331766
#
# Mon Sep 01 21:31:21 2025 AUC 0.920076160578595
#
# Mon Sep 01 21:32:05 2025 AUC 0.92892342161919
#
# Mon Sep 01 21:32:50 2025 AUC 0.924731017672862
#
# Mon Sep 01 21:33:21 2025 AUC 0.919703007841861
#
# Mon Sep 01 21:34:14 2025 AUC 0.926190417822194
#
# Mon Sep 01 21:34:34 2025 AUC 0.914270796639756
#
# Mon Sep 01 21:35:20 2025 AUC 0.920220617959115
#
# Mon Sep 01 21:35:42 2025 AUC 0.917885462057548
#
# Mon Sep 01 21:36:53 2025 AUC 0.928381203547913
#
# Mon Sep 01 21:37:07 2025 AUC 0.921957056401129
#
# Mon Sep 01 21:37:18 2025 AUC 0.928053970461873
#
# Mon Sep 01 21:38:38 2025 AUC 0.926043561303794
#
# Mon Sep 01 21:39:02 2025 AUC 0.927035973824848
#
# Mon Sep 01 21:39:55 2025 AUC 0.920123039990523
#
# Mon Sep 01 21:40:24 2025 AUC 0.927193982695846
#
# Mon Sep 01 21:41:02 2025 AUC 0.920197534845638
#
# Mon Sep 01 21:41:08 2025 AUC 0.92609774487993
#
# Mon Sep 01 21:41:19 2025 AUC 0.920303851453755
#
# Mon Sep 01 21:43:35 2025 AUC 0.929180557283841
#
# Mon Sep 01 21:44:21 2025 AUC 0.927670344242318
#
# Mon Sep 01 21:45:01 2025 AUC 0.917347884647342
#
# Mon Sep 01 21:45:32 2025 AUC 0.897961473587081
#
# Mon Sep 01 21:46:50 2025 AUC 0.927357402014202
#
# Mon Sep 01 21:47:31 2025 AUC 0.916081860639786
#
# Mon Sep 01 21:48:09 2025 AUC 0.925489082661321
#
# Mon Sep 01 21:48:11 2025 AUC 0.918634681213118
#
# [mbo] 0: num_iterations=602; learning_rate=0.137; feature_fraction=0.749; num_leaves=122; min_data_in_leaf=412; bagging_fraction=0.818; bagging_freq=3; lambda_l1=2.98; lambda_l2=4.02; min_gain_to_split=0.768 : y = 0.92 : 26.8 secs : initdesign
#
# [mbo] 0: num_iterations=737; learning_rate=0.0391; feature_fraction=0.892; num_leaves=181; min_data_in_leaf=512; bagging_fraction=0.755; bagging_freq=6; lambda_l1=3.04; lambda_l2=3.79; min_gain_to_split=0.831 : y = 0.929 : 43.7 secs : initdesign
#
# [mbo] 0: num_iterations=824; learning_rate=0.0979; feature_fraction=0.685; num_leaves=171; min_data_in_leaf=562; bagging_fraction=0.859; bagging_freq=6; lambda_l1=2.36; lambda_l2=3.23; min_gain_to_split=0.704 : y = 0.925 : 32.9 secs : initdesign
#
# [mbo] 0: num_iterations=1381; learning_rate=0.162; feature_fraction=0.797; num_leaves=96; min_data_in_leaf=689; bagging_fraction=0.747; bagging_freq=2; lambda_l1=4; lambda_l2=1.63; min_gain_to_split=0.211 : y = 0.919 : 61.6 secs : initdesign
#
# [mbo] 0: num_iterations=462; learning_rate=0.149; feature_fraction=0.817; num_leaves=152; min_data_in_leaf=481; bagging_fraction=0.791; bagging_freq=3; lambda_l1=3.63; lambda_l2=2.82; min_gain_to_split=0.682 : y = 0.922 : 24.3 secs : initdesign
#
# [mbo] 0: num_iterations=1247; learning_rate=0.141; feature_fraction=0.901; num_leaves=192; min_data_in_leaf=101; bagging_fraction=0.894; bagging_freq=7; lambda_l1=2.65; lambda_l2=1.96; min_gain_to_split=0.553 : y = 0.917 : 29.3 secs : initdesign
#
# [mbo] 0: num_iterations=1019; learning_rate=0.0549; feature_fraction=0.801; num_leaves=207; min_data_in_leaf=171; bagging_fraction=0.729; bagging_freq=5; lambda_l1=2.61; lambda_l2=3.01; min_gain_to_split=0.418 : y = 0.927 : 51.9 secs : initdesign
#
# [mbo] 0: num_iterations=1544; learning_rate=0.0838; feature_fraction=0.66; num_leaves=134; min_data_in_leaf=750; bagging_fraction=0.733; bagging_freq=7; lambda_l1=0.753; lambda_l2=2.39; min_gain_to_split=0.101 : y = 0.926 : 72.5 secs : initdesign
#
# [mbo] 0: num_iterations=1745; learning_rate=0.103; feature_fraction=0.758; num_leaves=108; min_data_in_leaf=883; bagging_fraction=0.692; bagging_freq=5; lambda_l1=4.56; lambda_l2=4.75; min_gain_to_split=0.232 : y = 0.923 : 66.4 secs : initdesign
#
# [mbo] 0: num_iterations=1093; learning_rate=0.126; feature_fraction=0.843; num_leaves=99; min_data_in_leaf=151; bagging_fraction=0.648; bagging_freq=2; lambda_l1=0.642; lambda_l2=0.843; min_gain_to_split=0.675 : y = 0.917 : 40.9 secs : initdesign
#
# [mbo] 0: num_iterations=538; learning_rate=0.159; feature_fraction=0.838; num_leaves=143; min_data_in_leaf=652; bagging_fraction=0.784; bagging_freq=10; lambda_l1=1.88; lambda_l2=2.32; min_gain_to_split=0.469 : y = 0.917 : 23.5 secs : initdesign
#
# [mbo] 0: num_iterations=910; learning_rate=0.0591; feature_fraction=0.786; num_leaves=45; min_data_in_leaf=273; bagging_fraction=0.842; bagging_freq=9; lambda_l1=1.05; lambda_l2=3.33; min_gain_to_split=0.607 : y = 0.928 : 44.4 secs : initdesign
#
# [mbo] 0: num_iterations=840; learning_rate=0.0803; feature_fraction=0.649; num_leaves=222; min_data_in_leaf=797; bagging_fraction=0.807; bagging_freq=3; lambda_l1=1.62; lambda_l2=3.69; min_gain_to_split=0.279 : y = 0.927 : 46.2 secs : initdesign
#
# [mbo] 0: num_iterations=1974; learning_rate=0.176; feature_fraction=0.916; num_leaves=202; min_data_in_leaf=543; bagging_fraction=0.967; bagging_freq=6; lambda_l1=0.0335; lambda_l2=1.54; min_gain_to_split=0.318 : y = 0.922 : 46.4 secs : initdesign
#
# [mbo] 0: num_iterations=1445; learning_rate=0.116; feature_fraction=0.973; num_leaves=88; min_data_in_leaf=595; bagging_fraction=0.617; bagging_freq=8; lambda_l1=1.67; lambda_l2=2.06; min_gain_to_split=0.331 : y = 0.92 : 54.8 secs : initdesign
#
# [mbo] 0: num_iterations=472; learning_rate=0.0301; feature_fraction=0.97; num_leaves=194; min_data_in_leaf=347; bagging_fraction=0.929; bagging_freq=5; lambda_l1=3.14; lambda_l2=0.133; min_gain_to_split=0.161 : y = 0.929 : 44.5 secs : initdesign
#
# [mbo] 0: num_iterations=1216; learning_rate=0.0954; feature_fraction=0.718; num_leaves=115; min_data_in_leaf=843; bagging_fraction=0.902; bagging_freq=2; lambda_l1=2.24; lambda_l2=1.45; min_gain_to_split=0.876 : y = 0.925 : 44.3 secs : initdesign
#
# [mbo] 0: num_iterations=711; learning_rate=0.123; feature_fraction=0.991; num_leaves=247; min_data_in_leaf=430; bagging_fraction=0.702; bagging_freq=6; lambda_l1=3.78; lambda_l2=3.95; min_gain_to_split=0.627 : y = 0.92 : 31.4 secs : initdesign
#
# [mbo] 0: num_iterations=1041; learning_rate=0.0519; feature_fraction=0.676; num_leaves=75; min_data_in_leaf=503; bagging_fraction=0.657; bagging_freq=4; lambda_l1=3.25; lambda_l2=0.438; min_gain_to_split=0.148 : y = 0.926 : 52.5 secs : initdesign
#
# [mbo] 0: num_iterations=339; learning_rate=0.192; feature_fraction=0.822; num_leaves=212; min_data_in_leaf=225; bagging_fraction=0.934; bagging_freq=1; lambda_l1=2.84; lambda_l2=2.9; min_gain_to_split=0.00948 : y = 0.914 : 20.7 secs : initdesign
#
# [mbo] 0: num_iterations=1533; learning_rate=0.144; feature_fraction=0.656; num_leaves=144; min_data_in_leaf=987; bagging_fraction=0.774; bagging_freq=10; lambda_l1=3.5; lambda_l2=0.353; min_gain_to_split=0.394 : y = 0.92 : 45.2 secs : initdesign
#
# [mbo] 0: num_iterations=623; learning_rate=0.171; feature_fraction=0.733; num_leaves=116; min_data_in_leaf=905; bagging_fraction=0.764; bagging_freq=1; lambda_l1=0.224; lambda_l2=4.74; min_gain_to_split=0.731 : y = 0.918 : 22.7 secs : initdesign
#
# [mbo] 0: num_iterations=1636; learning_rate=0.0434; feature_fraction=0.871; num_leaves=50; min_data_in_leaf=252; bagging_fraction=0.822; bagging_freq=10; lambda_l1=4.4; lambda_l2=4.42; min_gain_to_split=0.443 : y = 0.928 : 70.9 secs : initdesign
#
# [mbo] 0: num_iterations=222; learning_rate=0.113; feature_fraction=0.721; num_leaves=128; min_data_in_leaf=300; bagging_fraction=0.671; bagging_freq=8; lambda_l1=3.5; lambda_l2=3.5; min_gain_to_split=0.78 : y = 0.922 : 13.7 secs : initdesign
#
# [mbo] 0: num_iterations=116; learning_rate=0.0705; feature_fraction=0.938; num_leaves=256; min_data_in_leaf=326; bagging_fraction=0.948; bagging_freq=9; lambda_l1=1.44; lambda_l2=4.36; min_gain_to_split=0.821 : y = 0.928 : 11.2 secs : initdesign
#
# [mbo] 0: num_iterations=1926; learning_rate=0.0636; feature_fraction=0.856; num_leaves=173; min_data_in_leaf=861; bagging_fraction=0.639; bagging_freq=2; lambda_l1=5; lambda_l2=2.55; min_gain_to_split=0.975 : y = 0.926 : 79.5 secs : initdesign
#
# [mbo] 0: num_iterations=367; learning_rate=0.0358; feature_fraction=0.924; num_leaves=161; min_data_in_leaf=949; bagging_fraction=0.888; bagging_freq=4; lambda_l1=4.22; lambda_l2=3.61; min_gain_to_split=0.5 : y = 0.927 : 23.7 secs : initdesign
#
# [mbo] 0: num_iterations=1830; learning_rate=0.154; feature_fraction=0.86; num_leaves=67; min_data_in_leaf=456; bagging_fraction=0.958; bagging_freq=7; lambda_l1=1.36; lambda_l2=4.58; min_gain_to_split=0.0552 : y = 0.92 : 53.6 secs : initdesign
#
# [mbo] 0: num_iterations=267; learning_rate=0.0126; feature_fraction=0.632; num_leaves=160; min_data_in_leaf=27; bagging_fraction=0.997; bagging_freq=5; lambda_l1=2.49; lambda_l2=1.03; min_gain_to_split=0.531 : y = 0.927 : 29.3 secs : initdesign
#
# [mbo] 0: num_iterations=1176; learning_rate=0.131; feature_fraction=0.881; num_leaves=242; min_data_in_leaf=718; bagging_fraction=0.666; bagging_freq=8; lambda_l1=0.533; lambda_l2=1.19; min_gain_to_split=0.961 : y = 0.92 : 37.8 secs : initdesign
#
# [mbo] 0: num_iterations=104; learning_rate=0.087; feature_fraction=0.621; num_leaves=34; min_data_in_leaf=759; bagging_fraction=0.974; bagging_freq=10; lambda_l1=0.418; lambda_l2=1.79; min_gain_to_split=0.499 : y = 0.926 : 6.0 secs : initdesign
#
# [mbo] 0: num_iterations=190; learning_rate=0.182; feature_fraction=0.777; num_leaves=230; min_data_in_leaf=622; bagging_fraction=0.915; bagging_freq=4; lambda_l1=3.94; lambda_l2=0.527; min_gain_to_split=0.927 : y = 0.92 : 10.6 secs : initdesign
#
# [mbo] 0: num_iterations=1894; learning_rate=0.0221; feature_fraction=0.95; num_leaves=81; min_data_in_leaf=92; bagging_fraction=0.861; bagging_freq=9; lambda_l1=1.19; lambda_l2=0.031; min_gain_to_split=0.0461 : y = 0.929 : 136.3 secs : initdesign
#
# [mbo] 0: num_iterations=1655; learning_rate=0.075; feature_fraction=0.763; num_leaves=225; min_data_in_leaf=129; bagging_fraction=0.874; bagging_freq=1; lambda_l1=2.09; lambda_l2=4.89; min_gain_to_split=0.857 : y = 0.928 : 46.4 secs : initdesign
#
# [mbo] 0: num_iterations=1388; learning_rate=0.174; feature_fraction=0.695; num_leaves=36; min_data_in_leaf=197; bagging_fraction=0.832; bagging_freq=1; lambda_l1=4.65; lambda_l2=2.19; min_gain_to_split=0.182 : y = 0.917 : 39.5 secs : initdesign
#
# [mbo] 0: num_iterations=974; learning_rate=0.188; feature_fraction=0.707; num_leaves=239; min_data_in_leaf=46; bagging_fraction=0.605; bagging_freq=8; lambda_l1=1.75; lambda_l2=1.25; min_gain_to_split=0.0991 : y = 0.898 : 31.2 secs : initdesign
#
# [mbo] 0: num_iterations=1707; learning_rate=0.0288; feature_fraction=0.611; num_leaves=63; min_data_in_leaf=974; bagging_fraction=0.628; bagging_freq=3; lambda_l1=0.316; lambda_l2=0.904; min_gain_to_split=0.6 : y = 0.927 : 78.0 secs : initdesign
#
# [mbo] 0: num_iterations=2038; learning_rate=0.197; feature_fraction=0.989; num_leaves=55; min_data_in_leaf=815; bagging_fraction=0.716; bagging_freq=7; lambda_l1=4.26; lambda_l2=0.727; min_gain_to_split=0.917 : y = 0.916 : 40.7 secs : initdesign
#
# [mbo] 0: num_iterations=1314; learning_rate=0.107; feature_fraction=0.61; num_leaves=184; min_data_in_leaf=664; bagging_fraction=0.983; bagging_freq=9; lambda_l1=4.86; lambda_l2=4.15; min_gain_to_split=0.258 : y = 0.925 : 37.7 secs : initdesign
#
# [mbo] 0: num_iterations=32; learning_rate=0.0191; feature_fraction=0.958; num_leaves=78; min_data_in_leaf=386; bagging_fraction=0.683; bagging_freq=4; lambda_l1=0.921; lambda_l2=2.69; min_gain_to_split=0.371 : y = 0.919 : 2.3 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Sep 01 21:49:34 2025 AUC 0.928111616189488
#
# [mbo] 1: num_iterations=1846; learning_rate=0.039; feature_fraction=0.76; num_leaves=192; min_data_in_leaf=570; bagging_fraction=0.942; bagging_freq=8; lambda_l1=1.5; lambda_l2=0.531; min_gain_to_split=0.337 : y = 0.928 : 78.6 secs : infill_ei
#
# Mon Sep 01 21:50:18 2025 AUC 0.928355758528976
#
# [mbo] 2: num_iterations=929; learning_rate=0.0489; feature_fraction=0.643; num_leaves=185; min_data_in_leaf=392; bagging_fraction=0.849; bagging_freq=9; lambda_l1=3.96; lambda_l2=4.08; min_gain_to_split=0.952 : y = 0.928 : 43.4 secs : infill_ei
#
# Mon Sep 01 21:51:09 2025 AUC 0.927937351943185
#
# [mbo] 3: num_iterations=1440; learning_rate=0.0387; feature_fraction=0.898; num_leaves=150; min_data_in_leaf=142; bagging_fraction=0.922; bagging_freq=6; lambda_l1=3.37; lambda_l2=0.28; min_gain_to_split=0.812 : y = 0.928 : 49.3 secs : infill_ei
#
# Mon Sep 01 21:52:40 2025 AUC 0.928803407007755
#
# [mbo] 4: num_iterations=1170; learning_rate=0.0426; feature_fraction=0.905; num_leaves=186; min_data_in_leaf=424; bagging_fraction=0.984; bagging_freq=7; lambda_l1=2.47; lambda_l2=4.59; min_gain_to_split=0.0162 : y = 0.929 : 90.1 secs : infill_ei
#
# Mon Sep 01 21:53:10 2025 AUC 0.929356958205033
#
# [mbo] 5: num_iterations=497; learning_rate=0.0575; feature_fraction=0.862; num_leaves=210; min_data_in_leaf=527; bagging_fraction=0.982; bagging_freq=8; lambda_l1=3.99; lambda_l2=1.81; min_gain_to_split=0.565 : y = 0.929 : 28.2 secs : infill_ei
#
# Mon Sep 01 21:54:20 2025 AUC 0.92695973446065
#
# [mbo] 6: num_iterations=1749; learning_rate=0.0557; feature_fraction=0.897; num_leaves=219; min_data_in_leaf=671; bagging_fraction=0.818; bagging_freq=7; lambda_l1=1.32; lambda_l2=4.61; min_gain_to_split=0.803 : y = 0.927 : 69.4 secs : infill_ei
#
# Mon Sep 01 21:56:19 2025 AUC 0.92826876319366
#
# [mbo] 7: num_iterations=1634; learning_rate=0.0259; feature_fraction=0.664; num_leaves=123; min_data_in_leaf=255; bagging_fraction=0.888; bagging_freq=2; lambda_l1=3.18; lambda_l2=2.95; min_gain_to_split=0.141 : y = 0.928 : 117.7 secs : infill_ei
#
# Mon Sep 01 21:56:48 2025 AUC 0.928503035885278
#
# [mbo] 8: num_iterations=550; learning_rate=0.0455; feature_fraction=0.783; num_leaves=252; min_data_in_leaf=329; bagging_fraction=0.97; bagging_freq=1; lambda_l1=3.51; lambda_l2=4.16; min_gain_to_split=0.823 : y = 0.929 : 27.3 secs : infill_ei
#
# Mon Sep 01 21:57:56 2025 AUC 0.928878600044427
#
# [mbo] 9: num_iterations=828; learning_rate=0.0351; feature_fraction=0.82; num_leaves=114; min_data_in_leaf=216; bagging_fraction=0.958; bagging_freq=10; lambda_l1=3.24; lambda_l2=1.25; min_gain_to_split=0.0357 : y = 0.929 : 66.8 secs : infill_ei
#
# Mon Sep 01 21:58:08 2025 AUC 0.92796956931083
#
# [mbo] 10: num_iterations=163; learning_rate=0.0676; feature_fraction=0.823; num_leaves=205; min_data_in_leaf=494; bagging_fraction=0.822; bagging_freq=4; lambda_l1=4.99; lambda_l2=2.95; min_gain_to_split=0.876 : y = 0.928 : 11.6 secs : infill_ei
#
# Mon Sep 01 21:59:45 2025 AUC 0.929478534832127
#
# [mbo] 11: num_iterations=2009; learning_rate=0.0314; feature_fraction=0.617; num_leaves=37; min_data_in_leaf=293; bagging_fraction=0.874; bagging_freq=9; lambda_l1=1.92; lambda_l2=0.16; min_gain_to_split=0.106 : y = 0.929 : 95.7 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Mon Sep 01 22:00:37 2025 AUC 0.928630926738574
#
# [mbo] 12: num_iterations=773; learning_rate=0.0383; feature_fraction=0.804; num_leaves=190; min_data_in_leaf=518; bagging_fraction=0.994; bagging_freq=7; lambda_l1=0.766; lambda_l2=3.18; min_gain_to_split=0.556 : y = 0.929 : 45.6 secs : infill_ei
#
# Mon Sep 01 22:02:08 2025 AUC 0.92860827112526
#
# [mbo] 13: num_iterations=1749; learning_rate=0.0268; feature_fraction=0.851; num_leaves=34; min_data_in_leaf=607; bagging_fraction=0.839; bagging_freq=9; lambda_l1=3.34; lambda_l2=0.198; min_gain_to_split=0.000259 : y = 0.929 : 90.2 secs : infill_ei
#
# Mon Sep 01 22:03:02 2025 AUC 0.929383496947998
#
# [mbo] 14: num_iterations=777; learning_rate=0.0302; feature_fraction=0.941; num_leaves=230; min_data_in_leaf=294; bagging_fraction=0.983; bagging_freq=9; lambda_l1=4.38; lambda_l2=2.91; min_gain_to_split=0.388 : y = 0.929 : 52.4 secs : infill_ei
#
# Mon Sep 01 22:03:46 2025 AUC 0.928764754150188
#
# [mbo] 15: num_iterations=580; learning_rate=0.0432; feature_fraction=0.838; num_leaves=252; min_data_in_leaf=417; bagging_fraction=0.914; bagging_freq=8; lambda_l1=3.43; lambda_l2=3.23; min_gain_to_split=0.269 : y = 0.929 : 42.8 secs : infill_ei
#
# Mon Sep 01 22:06:11 2025 AUC 0.927824697335801
#
# [mbo] 16: num_iterations=2048; learning_rate=0.0364; feature_fraction=0.975; num_leaves=67; min_data_in_leaf=193; bagging_fraction=0.999; bagging_freq=8; lambda_l1=0.306; lambda_l2=1.12; min_gain_to_split=0.0105 : y = 0.928 : 143.8 secs : infill_ei
#
# Mon Sep 01 22:07:23 2025 AUC 0.928054799395948
#
# [mbo] 17: num_iterations=1437; learning_rate=0.0292; feature_fraction=0.603; num_leaves=135; min_data_in_leaf=543; bagging_fraction=0.764; bagging_freq=10; lambda_l1=2.69; lambda_l2=0.659; min_gain_to_split=0.641 : y = 0.928 : 70.8 secs : infill_ei
#
# Mon Sep 01 22:09:17 2025 AUC 0.929388157180088
#
# [mbo] 18: num_iterations=1190; learning_rate=0.0156; feature_fraction=0.896; num_leaves=204; min_data_in_leaf=293; bagging_fraction=0.998; bagging_freq=7; lambda_l1=4.22; lambda_l2=0.00434; min_gain_to_split=0.0259 : y = 0.929 : 112.6 secs : infill_ei
#
# Mon Sep 01 22:10:18 2025 AUC 0.929329496221603
#
# [mbo] 19: num_iterations=825; learning_rate=0.0301; feature_fraction=0.89; num_leaves=205; min_data_in_leaf=522; bagging_fraction=0.965; bagging_freq=5; lambda_l1=4.45; lambda_l2=0.82; min_gain_to_split=0.317 : y = 0.929 : 59.3 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Mon Sep 01 22:10:52 2025 AUC 0.929016982212372
#
# [mbo] 20: num_iterations=626; learning_rate=0.0612; feature_fraction=0.843; num_leaves=181; min_data_in_leaf=358; bagging_fraction=1; bagging_freq=6; lambda_l1=3.82; lambda_l2=4.25; min_gain_to_split=0.427 : y = 0.929 : 27.9 secs : infill_ei
#
# Mon Sep 01 22:12:11 2025 AUC 0.9295397511384
#
# [mbo] 21: num_iterations=1629; learning_rate=0.0153; feature_fraction=0.749; num_leaves=32; min_data_in_leaf=207; bagging_fraction=0.95; bagging_freq=10; lambda_l1=1.05; lambda_l2=0.488; min_gain_to_split=0.218 : y = 0.93 : 77.3 secs : infill_ei
#
# Mon Sep 01 22:14:00 2025 AUC 0.928860322725915
#
# [mbo] 22: num_iterations=1676; learning_rate=0.0258; feature_fraction=0.657; num_leaves=70; min_data_in_leaf=236; bagging_fraction=0.877; bagging_freq=10; lambda_l1=0.46; lambda_l2=0.0125; min_gain_to_split=0.00891 : y = 0.929 : 108.4 secs : infill_ei
#
# Mon Sep 01 22:15:25 2025 AUC 0.928405578588302
#
# [mbo] 23: num_iterations=1910; learning_rate=0.0215; feature_fraction=0.72; num_leaves=32; min_data_in_leaf=60; bagging_fraction=0.876; bagging_freq=10; lambda_l1=1.96; lambda_l2=2.53; min_gain_to_split=0.493 : y = 0.928 : 83.0 secs : infill_ei
#
# Mon Sep 01 22:16:45 2025 AUC 0.929894206964016
#
# [mbo] 24: num_iterations=954; learning_rate=0.02; feature_fraction=0.975; num_leaves=177; min_data_in_leaf=288; bagging_fraction=0.972; bagging_freq=10; lambda_l1=2.56; lambda_l2=0.00383; min_gain_to_split=0.366 : y = 0.93 : 78.6 secs : infill_ei
#
# Mon Sep 01 22:17:23 2025 AUC 0.926881322554265
#
# [mbo] 25: num_iterations=581; learning_rate=0.033; feature_fraction=1; num_leaves=194; min_data_in_leaf=475; bagging_fraction=0.996; bagging_freq=10; lambda_l1=3.05; lambda_l2=1.7; min_gain_to_split=0.946 : y = 0.927 : 37.2 secs : infill_ei
#
# Mon Sep 01 22:18:24 2025 AUC 0.928178482867051
#
# [mbo] 26: num_iterations=917; learning_rate=0.0255; feature_fraction=0.908; num_leaves=241; min_data_in_leaf=148; bagging_fraction=0.992; bagging_freq=7; lambda_l1=2.03; lambda_l2=0.012; min_gain_to_split=0.368 : y = 0.928 : 59.5 secs : infill_ei
#
# Mon Sep 01 22:19:45 2025 AUC 0.929215372478507
#
# [mbo] 27: num_iterations=1122; learning_rate=0.0118; feature_fraction=0.945; num_leaves=57; min_data_in_leaf=309; bagging_fraction=0.957; bagging_freq=10; lambda_l1=4.19; lambda_l2=0.695; min_gain_to_split=0.295 : y = 0.929 : 79.9 secs : infill_ei
#
# Mon Sep 01 22:21:09 2025 AUC 0.929125021105951
#
# [mbo] 28: num_iterations=1026; learning_rate=0.0209; feature_fraction=0.951; num_leaves=171; min_data_in_leaf=314; bagging_fraction=0.936; bagging_freq=9; lambda_l1=4.02; lambda_l2=0.013; min_gain_to_split=0.205 : y = 0.929 : 82.3 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Mon Sep 01 22:22:07 2025 AUC 0.927413435268807
#
# [mbo] 29: num_iterations=1308; learning_rate=0.0469; feature_fraction=0.614; num_leaves=188; min_data_in_leaf=521; bagging_fraction=0.777; bagging_freq=1; lambda_l1=3.43; lambda_l2=3.51; min_gain_to_split=0.678 : y = 0.927 : 53.3 secs : infill_ei
#
# Mon Sep 01 22:23:15 2025 AUC 0.929846064948588
#
# [mbo] 30: num_iterations=785; learning_rate=0.01; feature_fraction=0.926; num_leaves=197; min_data_in_leaf=561; bagging_fraction=0.995; bagging_freq=9; lambda_l1=3.35; lambda_l2=0.294; min_gain_to_split=0.0145 : y = 0.93 : 66.6 secs : infill_ei
#
# Mon Sep 01 22:25:35 2025 AUC 0.929106302949447
#
# [mbo] 31: num_iterations=1351; learning_rate=0.01; feature_fraction=0.928; num_leaves=153; min_data_in_leaf=292; bagging_fraction=0.999; bagging_freq=10; lambda_l1=2.56; lambda_l2=2.25; min_gain_to_split=0.124 : y = 0.929 : 138.8 secs : infill_ei
#
# Mon Sep 01 22:26:37 2025 AUC 0.930600115756766
#
# [mbo] 32: num_iterations=852; learning_rate=0.0155; feature_fraction=0.627; num_leaves=132; min_data_in_leaf=811; bagging_fraction=0.989; bagging_freq=6; lambda_l1=3.08; lambda_l2=0.0202; min_gain_to_split=0.000598 : y = 0.931 : 59.5 secs : infill_ei
#
# Mon Sep 01 22:27:19 2025 AUC 0.930045049200259
#
# [mbo] 33: num_iterations=559; learning_rate=0.0404; feature_fraction=0.609; num_leaves=218; min_data_in_leaf=740; bagging_fraction=0.992; bagging_freq=6; lambda_l1=2.93; lambda_l2=0.396; min_gain_to_split=0.0006 : y = 0.93 : 40.3 secs : infill_ei
#
# Mon Sep 01 22:28:22 2025 AUC 0.929029038630171
#
# [mbo] 34: num_iterations=993; learning_rate=0.0318; feature_fraction=0.628; num_leaves=167; min_data_in_leaf=957; bagging_fraction=0.987; bagging_freq=10; lambda_l1=3.43; lambda_l2=0.0837; min_gain_to_split=0.0152 : y = 0.929 : 61.9 secs : infill_ei
#
# Mon Sep 01 22:28:45 2025 AUC 0.927218075825251
#
# [mbo] 35: num_iterations=366; learning_rate=0.0695; feature_fraction=0.789; num_leaves=207; min_data_in_leaf=744; bagging_fraction=0.995; bagging_freq=1; lambda_l1=4.78; lambda_l2=0.00258; min_gain_to_split=0.177 : y = 0.927 : 21.4 secs : infill_ei
#
# Mon Sep 01 22:29:50 2025 AUC 0.929192761231799
#
# [mbo] 36: num_iterations=1172; learning_rate=0.0246; feature_fraction=0.639; num_leaves=35; min_data_in_leaf=666; bagging_fraction=0.952; bagging_freq=5; lambda_l1=2.3; lambda_l2=0.144; min_gain_to_split=0.369 : y = 0.929 : 63.1 secs : infill_ei
#
# Mon Sep 01 22:30:49 2025 AUC 0.92919114947902
#
# [mbo] 37: num_iterations=785; learning_rate=0.0104; feature_fraction=0.602; num_leaves=203; min_data_in_leaf=624; bagging_fraction=0.998; bagging_freq=8; lambda_l1=3.63; lambda_l2=3.62; min_gain_to_split=0.248 : y = 0.929 : 58.1 secs : infill_ei
#
# Mon Sep 01 22:34:38 2025 AUC 0.929313995165428
#
# [mbo] 38: num_iterations=2035; learning_rate=0.0101; feature_fraction=0.854; num_leaves=106; min_data_in_leaf=327; bagging_fraction=0.972; bagging_freq=5; lambda_l1=2.55; lambda_l2=0.00413; min_gain_to_split=0.204 : y = 0.929 : 227.0 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesiana.RDATA.
#
# Mon Sep 01 22:35:32 2025 AUC 0.929609976835399
#
# [mbo] 39: num_iterations=737; learning_rate=0.0105; feature_fraction=0.617; num_leaves=178; min_data_in_leaf=818; bagging_fraction=0.924; bagging_freq=8; lambda_l1=1.31; lambda_l2=0.0374; min_gain_to_split=0.402 : y = 0.93 : 48.6 secs : infill_ei
#
# Mon Sep 01 22:36:49 2025 AUC 0.929679558008633
#
# [mbo] 40: num_iterations=1089; learning_rate=0.0117; feature_fraction=0.68; num_leaves=103; min_data_in_leaf=940; bagging_fraction=0.996; bagging_freq=6; lambda_l1=0.93; lambda_l2=0.021; min_gain_to_split=0.00625 : y = 0.93 : 74.8 secs : infill_ei
#
# Mon Sep 01 22:38:30 2025 AUC 0.929059061837512
#
# [mbo] 41: num_iterations=1956; learning_rate=0.0128; feature_fraction=0.756; num_leaves=35; min_data_in_leaf=289; bagging_fraction=0.692; bagging_freq=5; lambda_l1=1.45; lambda_l2=0.0255; min_gain_to_split=0.341 : y = 0.929 : 99.5 secs : infill_ei
#
# Mon Sep 01 22:39:10 2025 AUC 0.928147151275456
#
# [mbo] 42: num_iterations=547; learning_rate=0.0108; feature_fraction=0.607; num_leaves=217; min_data_in_leaf=879; bagging_fraction=0.997; bagging_freq=5; lambda_l1=2.6; lambda_l2=0.0693; min_gain_to_split=0.0938 : y = 0.928 : 38.7 secs : infill_ei
#
# Mon Sep 01 22:40:03 2025 AUC 0.92868891129872
#
# [mbo] 43: num_iterations=655; learning_rate=0.0454; feature_fraction=0.886; num_leaves=136; min_data_in_leaf=761; bagging_fraction=0.978; bagging_freq=8; lambda_l1=1.32; lambda_l2=0.0756; min_gain_to_split=0.0172 : y = 0.929 : 51.5 secs : infill_ei
#
# Mon Sep 01 22:41:02 2025 AUC 0.928887157842042
#
# [mbo] 44: num_iterations=795; learning_rate=0.0395; feature_fraction=0.717; num_leaves=140; min_data_in_leaf=658; bagging_fraction=0.978; bagging_freq=6; lambda_l1=4.94; lambda_l2=3.54; min_gain_to_split=0.00235 : y = 0.929 : 56.6 secs : infill_ei
#
# Mon Sep 01 22:42:15 2025 AUC 0.930265716336088
#
# [mbo] 45: num_iterations=939; learning_rate=0.0138; feature_fraction=0.615; num_leaves=138; min_data_in_leaf=597; bagging_fraction=0.975; bagging_freq=8; lambda_l1=2.34; lambda_l2=0.323; min_gain_to_split=0.0137 : y = 0.93 : 71.9 secs : infill_ei
#
# Mon Sep 01 22:43:35 2025 AUC 0.928800014720915
#
# [mbo] 46: num_iterations=1287; learning_rate=0.0161; feature_fraction=0.651; num_leaves=168; min_data_in_leaf=804; bagging_fraction=0.837; bagging_freq=6; lambda_l1=2.71; lambda_l2=0.0633; min_gain_to_split=0.00542 : y = 0.929 : 77.8 secs : infill_ei
#
# Mon Sep 01 22:45:20 2025 AUC 0.92801658198172
#
# [mbo] 47: num_iterations=1956; learning_rate=0.0102; feature_fraction=0.673; num_leaves=43; min_data_in_leaf=878; bagging_fraction=0.791; bagging_freq=8; lambda_l1=1.4; lambda_l2=0.0205; min_gain_to_split=0.485 : y = 0.928 : 103.9 secs : infill_ei
#
# Saved the current state after iteration 48 in the file bayesiana.RDATA.
#
# Mon Sep 01 22:45:50 2025 AUC 0.92706876130249
#
# [mbo] 48: num_iterations=338; learning_rate=0.0644; feature_fraction=0.6; num_leaves=226; min_data_in_leaf=770; bagging_fraction=0.973; bagging_freq=10; lambda_l1=3.61; lambda_l2=3.89; min_gain_to_split=0.532 : y = 0.927 : 22.0 secs : infill_ei
#
# Mon Sep 01 22:47:05 2025 AUC 0.926699790679099
#
# [mbo] 49: num_iterations=1927; learning_rate=0.0399; feature_fraction=0.746; num_leaves=32; min_data_in_leaf=193; bagging_fraction=0.656; bagging_freq=7; lambda_l1=2.85; lambda_l2=0.144; min_gain_to_split=0.884 : y = 0.927 : 73.5 secs : infill_ei
#
# Mon Sep 01 22:47:43 2025 AUC 0.928779325823991
#
# [mbo] 50: num_iterations=634; learning_rate=0.0408; feature_fraction=0.611; num_leaves=179; min_data_in_leaf=320; bagging_fraction=0.997; bagging_freq=7; lambda_l1=4.28; lambda_l2=0.0721; min_gain_to_split=0.467 : y = 0.929 : 36.4 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"    "learning_rate"     "feature_fraction"
#  [4] "num_leaves"        "min_data_in_leaf"  "bagging_fraction"
#  [7] "bagging_freq"      "lambda_l1"         "lambda_l2"
# [10] "min_gain_to_split" "y"                 "dob"
# [13] "eol"               "error.message"     "exec.time"
# [16] "ei"                "error.model"       "train.time"
# [19] "prop.type"         "propose.time"      "se"
# [22] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:            852    0.01551408        0.6265432        132              811
#    bagging_fraction bagging_freq lambda_l1  lambda_l2 min_gain_to_split
#               <num>        <int>     <num>      <num>             <num>
# 1:        0.9890043            6  3.075106 0.02021545      0.0005976098
# [1] 0.9306001

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_col_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100019
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0.0005976098
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 3.075106
#
# $lambda_l2
# [1] 0.02021545
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.9890043
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] TRUE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 0
#
# $skip_drop
# [1] 0
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 852
#
# $learning_rate
# [1] 0.01551408
#
# $feature_fraction
# [1] 0.6265432
#
# $num_leaves
# [1] 132
#
# $min_data_in_leaf
# [1] 811
#
# $bagging_freq
# [1] 6

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025 B
# Successfully submitted to Data Mining, Analista Sr 2025 B
# Successfully submitted to Data Mining, Analista Sr 2025 B
# Successfully submitted to Data Mining, Analista Sr 2025 B
# Successfully submitted to Data Mining, Analista Sr 2025 B

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Sep 01 22:49:08 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
